# %% [markdown]
# #### Day 13 - A
# Claw machines with 2 buttons that change the X and Y position of the claw.
#
# Find what combination of buttons can reach the prize for each machine.

# %%
#Import Libraries and settings
from sympy import Eq, solve
from sympy.abc import a, b, x, y

settings = {
    "day": 13,
    "test_data": 0
}

# %%
def parse_button(b_text):
    button = b_text.split(":")[0][-1]
    x_val = int(b_text.split("+")[1].split(",")[0])
    y_val = int(b_text.split("+")[2])

    return {
        "id": button,
        "x": x_val,
        "y": y_val
        }

def parse_prize(p_text):
    x_prize = int(p_text.split(" ")[1].split("=")[1][:-1])
    y_prize = int(p_text.split(" ")[2].split("=")[1])

    return {
        "x": x_prize,
        "y": y_prize
        }

#Load Input
def load_input(settings):
    #Derrive input file name
    if settings["test_data"]:
        data_subdir = "test"
    else:
        data_subdir = "actual"

    data_fp = f"./../input/{data_subdir}/{settings["day"]}.txt"

    #Open and read the file
    with open(data_fp) as f:
        lines = f.read().split('\n')

    eqs = []
    for idx_3 in range(0, len(lines), 4):
        idx_1 = int(idx_3/3)
        eq = {
            "buttons":[]
        }
        eq["buttons"].append(parse_button(lines[idx_3]))
        eq["buttons"].append(parse_button(lines[idx_3 + 1]))
        eq["prize"] = parse_prize(lines[idx_3 + 2])
        eqs.append(eq)

    return eqs

data_in = load_input(settings)

# %%
#Find the solution for a given machine
def solve_for_prize (machine):
    button_a = machine["buttons"][0]
    button_b = machine["buttons"][1]
    prize = machine["prize"]

    #Build simutaneous equations
    x_eq = Eq(button_a["x"]*a + button_b["x"]*b, prize["x"])
    y_eq = Eq(button_a["y"]*a + button_b["y"]*b, prize["y"])

    #Solve equations
    sol = solve([x_eq, y_eq])
    sol_a = sol[a].evalf()
    sol_b = sol[b].evalf()

    #Check if solution is a whole number
    if (
        (sol_a == int(sol_a)) and
        (sol_b == int(sol_b))
        ):
        #Ignore solutions with more than 100 presses
        if sol_a > 100 or sol_b > 100:
            return False
        return (int(sol_a), int(sol_b))
    else:
        return False

def process_machines(machines):
    subtotal = 0
    for machine in machines:
        print(machine)
        res = solve_for_prize(machine)

        if res:
            subtotal += 3*res[0] + res[1]

    return subtotal

# %%
process_machines(data_in)
# Out:
# {'buttons': [{'id': 'A', 'x': 15, 'y': 29}, {'id': 'B', 'x': 56, 'y': 23}], 'prize': {'x': 9778, 'y': 15506}}
# {'buttons': [{'id': 'A', 'x': 28, 'y': 37}, {'id': 'B', 'x': 69, 'y': 17}], 'prize': {'x': 5356, 'y': 3517}}
# {'buttons': [{'id': 'A', 'x': 47, 'y': 79}, {'id': 'B', 'x': 84, 'y': 16}], 'prize': {'x': 7244, 'y': 1660}}
# {'buttons': [{'id': 'A', 'x': 11, 'y': 39}, {'id': 'B', 'x': 48, 'y': 16}], 'prize': {'x': 11476, 'y': 14884}}
# {'buttons': [{'id': 'A', 'x': 12, 'y': 79}, {'id': 'B', 'x': 60, 'y': 14}], 'prize': {'x': 9836, 'y': 12272}}
# {'buttons': [{'id': 'A', 'x': 33, 'y': 50}, {'id': 'B', 'x': 26, 'y': 12}], 'prize': {'x': 6772, 'y': 15880}}
# {'buttons': [{'id': 'A', 'x': 66, 'y': 19}, {'id': 'B', 'x': 12, 'y': 38}], 'prize': {'x': 14888, 'y': 4452}}
# {'buttons': [{'id': 'A', 'x': 16, 'y': 42}, {'id': 'B', 'x': 64, 'y': 15}], 'prize': {'x': 16928, 'y': 7838}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 32}, {'id': 'B', 'x': 54, 'y': 20}], 'prize': {'x': 5073, 'y': 14580}}
# {'buttons': [{'id': 'A', 'x': 19, 'y': 36}, {'id': 'B', 'x': 56, 'y': 29}], 'prize': {'x': 1226, 'y': 1814}}
# {'buttons': [{'id': 'A', 'x': 79, 'y': 32}, {'id': 'B', 'x': 18, 'y': 66}], 'prize': {'x': 14753, 'y': 5438}}
# {'buttons': [{'id': 'A', 'x': 79, 'y': 15}, {'id': 'B', 'x': 16, 'y': 82}], 'prize': {'x': 2878, 'y': 14244}}
# {'buttons': [{'id': 'A', 'x': 78, 'y': 25}, {'id': 'B', 'x': 14, 'y': 62}], 'prize': {'x': 7916, 'y': 3975}}
# {'buttons': [{'id': 'A', 'x': 59, 'y': 14}, {'id': 'B', 'x': 21, 'y': 71}], 'prize': {'x': 16664, 'y': 10839}}
# {'buttons': [{'id': 'A', 'x': 67, 'y': 19}, {'id': 'B', 'x': 18, 'y': 73}], 'prize': {'x': 14219, 'y': 7633}}
# {'buttons': [{'id': 'A', 'x': 83, 'y': 13}, {'id': 'B', 'x': 91, 'y': 85}], 'prize': {'x': 14292, 'y': 8252}}
# {'buttons': [{'id': 'A', 'x': 92, 'y': 29}, {'id': 'B', 'x': 30, 'y': 94}], 'prize': {'x': 7532, 'y': 7785}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 65}, {'id': 'B', 'x': 71, 'y': 20}], 'prize': {'x': 260, 'y': 15580}}
# {'buttons': [{'id': 'A', 'x': 74, 'y': 29}, {'id': 'B', 'x': 42, 'y': 62}], 'prize': {'x': 4438, 'y': 5428}}
# {'buttons': [{'id': 'A', 'x': 11, 'y': 52}, {'id': 'B', 'x': 45, 'y': 19}], 'prize': {'x': 17422, 'y': 11778}}
# {'buttons': [{'id': 'A', 'x': 14, 'y': 74}, {'id': 'B', 'x': 82, 'y': 12}], 'prize': {'x': 6218, 'y': 15688}}
# {'buttons': [{'id': 'A', 'x': 60, 'y': 40}, {'id': 'B', 'x': 18, 'y': 54}], 'prize': {'x': 1398, 'y': 1814}}
# {'buttons': [{'id': 'A', 'x': 28, 'y': 76}, {'id': 'B', 'x': 56, 'y': 16}], 'prize': {'x': 12856, 'y': 3760}}
# {'buttons': [{'id': 'A', 'x': 73, 'y': 11}, {'id': 'B', 'x': 55, 'y': 66}], 'prize': {'x': 2831, 'y': 946}}
# {'buttons': [{'id': 'A', 'x': 16, 'y': 48}, {'id': 'B', 'x': 67, 'y': 32}], 'prize': {'x': 18491, 'y': 19184}}
# {'buttons': [{'id': 'A', 'x': 84, 'y': 16}, {'id': 'B', 'x': 20, 'y': 71}], 'prize': {'x': 8892, 'y': 6733}}
# {'buttons': [{'id': 'A', 'x': 91, 'y': 14}, {'id': 'B', 'x': 66, 'y': 89}], 'prize': {'x': 6287, 'y': 4673}}
# {'buttons': [{'id': 'A', 'x': 18, 'y': 62}, {'id': 'B', 'x': 37, 'y': 15}], 'prize': {'x': 16550, 'y': 14482}}
# {'buttons': [{'id': 'A', 'x': 20, 'y': 74}, {'id': 'B', 'x': 52, 'y': 15}], 'prize': {'x': 13004, 'y': 10683}}
# {'buttons': [{'id': 'A', 'x': 68, 'y': 35}, {'id': 'B', 'x': 14, 'y': 54}], 'prize': {'x': 14024, 'y': 8701}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 39}, {'id': 'B', 'x': 41, 'y': 23}], 'prize': {'x': 1685, 'y': 3355}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 76}, {'id': 'B', 'x': 82, 'y': 22}], 'prize': {'x': 10323, 'y': 9654}}
# {'buttons': [{'id': 'A', 'x': 11, 'y': 83}, {'id': 'B', 'x': 84, 'y': 14}], 'prize': {'x': 7519, 'y': 3489}}
# {'buttons': [{'id': 'A', 'x': 33, 'y': 84}, {'id': 'B', 'x': 80, 'y': 32}], 'prize': {'x': 8033, 'y': 8948}}
# {'buttons': [{'id': 'A', 'x': 72, 'y': 42}, {'id': 'B', 'x': 35, 'y': 71}], 'prize': {'x': 9117, 'y': 8505}}
# {'buttons': [{'id': 'A', 'x': 18, 'y': 40}, {'id': 'B', 'x': 90, 'y': 31}], 'prize': {'x': 9234, 'y': 6493}}
# {'buttons': [{'id': 'A', 'x': 19, 'y': 68}, {'id': 'B', 'x': 66, 'y': 61}], 'prize': {'x': 7205, 'y': 10543}}
# {'buttons': [{'id': 'A', 'x': 55, 'y': 29}, {'id': 'B', 'x': 21, 'y': 34}], 'prize': {'x': 5591, 'y': 14886}}
# {'buttons': [{'id': 'A', 'x': 46, 'y': 22}, {'id': 'B', 'x': 26, 'y': 56}], 'prize': {'x': 2070, 'y': 13584}}
# {'buttons': [{'id': 'A', 'x': 19, 'y': 50}, {'id': 'B', 'x': 62, 'y': 22}], 'prize': {'x': 12087, 'y': 7636}}
# {'buttons': [{'id': 'A', 'x': 16, 'y': 82}, {'id': 'B', 'x': 80, 'y': 12}], 'prize': {'x': 8592, 'y': 3598}}
# {'buttons': [{'id': 'A', 'x': 23, 'y': 11}, {'id': 'B', 'x': 13, 'y': 23}], 'prize': {'x': 15241, 'y': 9445}}
# {'buttons': [{'id': 'A', 'x': 26, 'y': 45}, {'id': 'B', 'x': 39, 'y': 19}], 'prize': {'x': 10364, 'y': 9006}}
# {'buttons': [{'id': 'A', 'x': 51, 'y': 19}, {'id': 'B', 'x': 14, 'y': 28}], 'prize': {'x': 12489, 'y': 16499}}
# {'buttons': [{'id': 'A', 'x': 12, 'y': 23}, {'id': 'B', 'x': 66, 'y': 41}], 'prize': {'x': 19556, 'y': 1703}}
# {'buttons': [{'id': 'A', 'x': 69, 'y': 34}, {'id': 'B', 'x': 12, 'y': 44}], 'prize': {'x': 6708, 'y': 5324}}
# {'buttons': [{'id': 'A', 'x': 91, 'y': 31}, {'id': 'B', 'x': 31, 'y': 90}], 'prize': {'x': 9392, 'y': 9078}}
# {'buttons': [{'id': 'A', 'x': 14, 'y': 40}, {'id': 'B', 'x': 71, 'y': 28}], 'prize': {'x': 6790, 'y': 9048}}
# {'buttons': [{'id': 'A', 'x': 32, 'y': 34}, {'id': 'B', 'x': 93, 'y': 23}], 'prize': {'x': 2137, 'y': 1285}}
# {'buttons': [{'id': 'A', 'x': 11, 'y': 97}, {'id': 'B', 'x': 29, 'y': 18}], 'prize': {'x': 2742, 'y': 5399}}
# {'buttons': [{'id': 'A', 'x': 26, 'y': 65}, {'id': 'B', 'x': 49, 'y': 14}], 'prize': {'x': 19356, 'y': 15652}}
# {'buttons': [{'id': 'A', 'x': 29, 'y': 74}, {'id': 'B', 'x': 97, 'y': 28}], 'prize': {'x': 8750, 'y': 8498}}
# {'buttons': [{'id': 'A', 'x': 19, 'y': 80}, {'id': 'B', 'x': 87, 'y': 27}], 'prize': {'x': 7748, 'y': 3442}}
# {'buttons': [{'id': 'A', 'x': 11, 'y': 35}, {'id': 'B', 'x': 61, 'y': 30}], 'prize': {'x': 9249, 'y': 11160}}
# {'buttons': [{'id': 'A', 'x': 18, 'y': 48}, {'id': 'B', 'x': 61, 'y': 33}], 'prize': {'x': 4962, 'y': 9884}}
# {'buttons': [{'id': 'A', 'x': 47, 'y': 75}, {'id': 'B', 'x': 74, 'y': 28}], 'prize': {'x': 4073, 'y': 3887}}
# {'buttons': [{'id': 'A', 'x': 52, 'y': 13}, {'id': 'B', 'x': 39, 'y': 71}], 'prize': {'x': 7894, 'y': 8476}}
# {'buttons': [{'id': 'A', 'x': 54, 'y': 98}, {'id': 'B', 'x': 65, 'y': 19}], 'prize': {'x': 9023, 'y': 8557}}
# {'buttons': [{'id': 'A', 'x': 86, 'y': 11}, {'id': 'B', 'x': 16, 'y': 45}], 'prize': {'x': 6424, 'y': 2368}}
# {'buttons': [{'id': 'A', 'x': 14, 'y': 39}, {'id': 'B', 'x': 42, 'y': 19}], 'prize': {'x': 6374, 'y': 13761}}
# {'buttons': [{'id': 'A', 'x': 23, 'y': 42}, {'id': 'B', 'x': 34, 'y': 15}], 'prize': {'x': 5778, 'y': 13340}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 21}, {'id': 'B', 'x': 26, 'y': 13}], 'prize': {'x': 2551, 'y': 2611}}
# {'buttons': [{'id': 'A', 'x': 23, 'y': 88}, {'id': 'B', 'x': 62, 'y': 53}], 'prize': {'x': 3181, 'y': 8118}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 90}, {'id': 'B', 'x': 87, 'y': 27}], 'prize': {'x': 3907, 'y': 7488}}
# {'buttons': [{'id': 'A', 'x': 61, 'y': 23}, {'id': 'B', 'x': 70, 'y': 98}], 'prize': {'x': 5855, 'y': 4141}}
# {'buttons': [{'id': 'A', 'x': 17, 'y': 54}, {'id': 'B', 'x': 49, 'y': 27}], 'prize': {'x': 16754, 'y': 14138}}
# {'buttons': [{'id': 'A', 'x': 56, 'y': 22}, {'id': 'B', 'x': 23, 'y': 41}], 'prize': {'x': 4126, 'y': 10692}}
# {'buttons': [{'id': 'A', 'x': 41, 'y': 15}, {'id': 'B', 'x': 39, 'y': 66}], 'prize': {'x': 2716, 'y': 19559}}
# {'buttons': [{'id': 'A', 'x': 18, 'y': 74}, {'id': 'B', 'x': 61, 'y': 14}], 'prize': {'x': 8171, 'y': 16866}}
# {'buttons': [{'id': 'A', 'x': 12, 'y': 19}, {'id': 'B', 'x': 49, 'y': 25}], 'prize': {'x': 19656, 'y': 12181}}
# {'buttons': [{'id': 'A', 'x': 33, 'y': 77}, {'id': 'B', 'x': 51, 'y': 13}], 'prize': {'x': 2009, 'y': 7445}}
# {'buttons': [{'id': 'A', 'x': 64, 'y': 12}, {'id': 'B', 'x': 19, 'y': 69}], 'prize': {'x': 2536, 'y': 4140}}
# {'buttons': [{'id': 'A', 'x': 24, 'y': 76}, {'id': 'B', 'x': 50, 'y': 15}], 'prize': {'x': 13228, 'y': 19482}}
# {'buttons': [{'id': 'A', 'x': 65, 'y': 20}, {'id': 'B', 'x': 17, 'y': 40}], 'prize': {'x': 19173, 'y': 900}}
# {'buttons': [{'id': 'A', 'x': 11, 'y': 91}, {'id': 'B', 'x': 93, 'y': 26}], 'prize': {'x': 3024, 'y': 7176}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 92}, {'id': 'B', 'x': 54, 'y': 16}], 'prize': {'x': 4219, 'y': 7156}}
# {'buttons': [{'id': 'A', 'x': 72, 'y': 45}, {'id': 'B', 'x': 17, 'y': 36}], 'prize': {'x': 4731, 'y': 8729}}
# {'buttons': [{'id': 'A', 'x': 29, 'y': 57}, {'id': 'B', 'x': 46, 'y': 21}], 'prize': {'x': 4987, 'y': 4790}}
# {'buttons': [{'id': 'A', 'x': 54, 'y': 15}, {'id': 'B', 'x': 43, 'y': 83}], 'prize': {'x': 8158, 'y': 2094}}
# {'buttons': [{'id': 'A', 'x': 54, 'y': 35}, {'id': 'B', 'x': 37, 'y': 79}], 'prize': {'x': 2189, 'y': 2024}}
# {'buttons': [{'id': 'A', 'x': 55, 'y': 23}, {'id': 'B', 'x': 24, 'y': 56}], 'prize': {'x': 326, 'y': 9926}}
# {'buttons': [{'id': 'A', 'x': 12, 'y': 26}, {'id': 'B', 'x': 82, 'y': 45}], 'prize': {'x': 7984, 'y': 5624}}
# {'buttons': [{'id': 'A', 'x': 31, 'y': 85}, {'id': 'B', 'x': 54, 'y': 32}], 'prize': {'x': 3608, 'y': 4670}}
# {'buttons': [{'id': 'A', 'x': 92, 'y': 18}, {'id': 'B', 'x': 73, 'y': 65}], 'prize': {'x': 13368, 'y': 6470}}
# {'buttons': [{'id': 'A', 'x': 11, 'y': 44}, {'id': 'B', 'x': 45, 'y': 27}], 'prize': {'x': 1541, 'y': 6095}}
# {'buttons': [{'id': 'A', 'x': 47, 'y': 20}, {'id': 'B', 'x': 23, 'y': 60}], 'prize': {'x': 7017, 'y': 1780}}
# {'buttons': [{'id': 'A', 'x': 47, 'y': 16}, {'id': 'B', 'x': 19, 'y': 63}], 'prize': {'x': 1975, 'y': 6193}}
# {'buttons': [{'id': 'A', 'x': 52, 'y': 24}, {'id': 'B', 'x': 29, 'y': 57}], 'prize': {'x': 15344, 'y': 476}}
# {'buttons': [{'id': 'A', 'x': 72, 'y': 38}, {'id': 'B', 'x': 16, 'y': 38}], 'prize': {'x': 11112, 'y': 10114}}
# {'buttons': [{'id': 'A', 'x': 79, 'y': 53}, {'id': 'B', 'x': 35, 'y': 83}], 'prize': {'x': 7573, 'y': 6271}}
# {'buttons': [{'id': 'A', 'x': 32, 'y': 59}, {'id': 'B', 'x': 46, 'y': 22}], 'prize': {'x': 14552, 'y': 15584}}
# {'buttons': [{'id': 'A', 'x': 11, 'y': 34}, {'id': 'B', 'x': 82, 'y': 48}], 'prize': {'x': 4794, 'y': 15316}}
# {'buttons': [{'id': 'A', 'x': 22, 'y': 92}, {'id': 'B', 'x': 59, 'y': 51}], 'prize': {'x': 2992, 'y': 3900}}
# {'buttons': [{'id': 'A', 'x': 84, 'y': 62}, {'id': 'B', 'x': 32, 'y': 98}], 'prize': {'x': 3312, 'y': 7800}}
# {'buttons': [{'id': 'A', 'x': 39, 'y': 74}, {'id': 'B', 'x': 67, 'y': 25}], 'prize': {'x': 2569, 'y': 4466}}
# {'buttons': [{'id': 'A', 'x': 16, 'y': 74}, {'id': 'B', 'x': 81, 'y': 23}], 'prize': {'x': 19595, 'y': 8401}}
# {'buttons': [{'id': 'A', 'x': 95, 'y': 59}, {'id': 'B', 'x': 43, 'y': 84}], 'prize': {'x': 9271, 'y': 9883}}
# {'buttons': [{'id': 'A', 'x': 37, 'y': 16}, {'id': 'B', 'x': 29, 'y': 89}], 'prize': {'x': 3278, 'y': 3329}}
# {'buttons': [{'id': 'A', 'x': 19, 'y': 84}, {'id': 'B', 'x': 77, 'y': 14}], 'prize': {'x': 1081, 'y': 1068}}
# {'buttons': [{'id': 'A', 'x': 12, 'y': 19}, {'id': 'B', 'x': 81, 'y': 12}], 'prize': {'x': 2694, 'y': 1243}}
# {'buttons': [{'id': 'A', 'x': 14, 'y': 61}, {'id': 'B', 'x': 78, 'y': 35}], 'prize': {'x': 11906, 'y': 7355}}
# {'buttons': [{'id': 'A', 'x': 32, 'y': 68}, {'id': 'B', 'x': 93, 'y': 37}], 'prize': {'x': 1948, 'y': 2212}}
# {'buttons': [{'id': 'A', 'x': 11, 'y': 53}, {'id': 'B', 'x': 83, 'y': 30}], 'prize': {'x': 13873, 'y': 6484}}
# {'buttons': [{'id': 'A', 'x': 34, 'y': 58}, {'id': 'B', 'x': 33, 'y': 14}], 'prize': {'x': 6369, 'y': 7016}}
# {'buttons': [{'id': 'A', 'x': 59, 'y': 84}, {'id': 'B', 'x': 69, 'y': 21}], 'prize': {'x': 6564, 'y': 6951}}
# {'buttons': [{'id': 'A', 'x': 49, 'y': 23}, {'id': 'B', 'x': 18, 'y': 55}], 'prize': {'x': 12360, 'y': 16699}}
# {'buttons': [{'id': 'A', 'x': 16, 'y': 64}, {'id': 'B', 'x': 70, 'y': 15}], 'prize': {'x': 13108, 'y': 4682}}
# {'buttons': [{'id': 'A', 'x': 99, 'y': 49}, {'id': 'B', 'x': 28, 'y': 72}], 'prize': {'x': 7677, 'y': 4323}}
# {'buttons': [{'id': 'A', 'x': 58, 'y': 16}, {'id': 'B', 'x': 12, 'y': 32}], 'prize': {'x': 17836, 'y': 8224}}
# {'buttons': [{'id': 'A', 'x': 56, 'y': 17}, {'id': 'B', 'x': 34, 'y': 72}], 'prize': {'x': 6074, 'y': 12646}}
# {'buttons': [{'id': 'A', 'x': 78, 'y': 50}, {'id': 'B', 'x': 15, 'y': 36}], 'prize': {'x': 5702, 'y': 4428}}
# {'buttons': [{'id': 'A', 'x': 39, 'y': 62}, {'id': 'B', 'x': 27, 'y': 14}], 'prize': {'x': 7943, 'y': 10454}}
# {'buttons': [{'id': 'A', 'x': 90, 'y': 21}, {'id': 'B', 'x': 71, 'y': 76}], 'prize': {'x': 6110, 'y': 2020}}
# {'buttons': [{'id': 'A', 'x': 12, 'y': 60}, {'id': 'B', 'x': 74, 'y': 33}], 'prize': {'x': 12030, 'y': 11219}}
# {'buttons': [{'id': 'A', 'x': 49, 'y': 15}, {'id': 'B', 'x': 14, 'y': 59}], 'prize': {'x': 5737, 'y': 14864}}
# {'buttons': [{'id': 'A', 'x': 69, 'y': 22}, {'id': 'B', 'x': 13, 'y': 38}], 'prize': {'x': 2917, 'y': 4214}}
# {'buttons': [{'id': 'A', 'x': 37, 'y': 17}, {'id': 'B', 'x': 30, 'y': 62}], 'prize': {'x': 1259, 'y': 3935}}
# {'buttons': [{'id': 'A', 'x': 32, 'y': 45}, {'id': 'B', 'x': 75, 'y': 16}], 'prize': {'x': 4204, 'y': 2691}}
# {'buttons': [{'id': 'A', 'x': 85, 'y': 34}, {'id': 'B', 'x': 11, 'y': 49}], 'prize': {'x': 1698, 'y': 1705}}
# {'buttons': [{'id': 'A', 'x': 68, 'y': 40}, {'id': 'B', 'x': 41, 'y': 80}], 'prize': {'x': 7662, 'y': 5960}}
# {'buttons': [{'id': 'A', 'x': 23, 'y': 61}, {'id': 'B', 'x': 57, 'y': 26}], 'prize': {'x': 10389, 'y': 14139}}
# {'buttons': [{'id': 'A', 'x': 16, 'y': 40}, {'id': 'B', 'x': 33, 'y': 12}], 'prize': {'x': 6497, 'y': 9884}}
# {'buttons': [{'id': 'A', 'x': 31, 'y': 96}, {'id': 'B', 'x': 43, 'y': 38}], 'prize': {'x': 5090, 'y': 11290}}
# {'buttons': [{'id': 'A', 'x': 21, 'y': 42}, {'id': 'B', 'x': 41, 'y': 23}], 'prize': {'x': 14722, 'y': 8011}}
# {'buttons': [{'id': 'A', 'x': 73, 'y': 23}, {'id': 'B', 'x': 16, 'y': 68}], 'prize': {'x': 347, 'y': 613}}
# {'buttons': [{'id': 'A', 'x': 50, 'y': 33}, {'id': 'B', 'x': 20, 'y': 40}], 'prize': {'x': 17580, 'y': 17960}}
# {'buttons': [{'id': 'A', 'x': 69, 'y': 15}, {'id': 'B', 'x': 20, 'y': 59}], 'prize': {'x': 12087, 'y': 708}}
# {'buttons': [{'id': 'A', 'x': 82, 'y': 39}, {'id': 'B', 'x': 30, 'y': 92}], 'prize': {'x': 1992, 'y': 4834}}
# {'buttons': [{'id': 'A', 'x': 40, 'y': 13}, {'id': 'B', 'x': 13, 'y': 57}], 'prize': {'x': 19670, 'y': 4897}}
# {'buttons': [{'id': 'A', 'x': 68, 'y': 48}, {'id': 'B', 'x': 11, 'y': 24}], 'prize': {'x': 3321, 'y': 3272}}
# {'buttons': [{'id': 'A', 'x': 15, 'y': 34}, {'id': 'B', 'x': 37, 'y': 22}], 'prize': {'x': 1656, 'y': 1712}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 48}, {'id': 'B', 'x': 58, 'y': 18}], 'prize': {'x': 13830, 'y': 2180}}
# {'buttons': [{'id': 'A', 'x': 37, 'y': 12}, {'id': 'B', 'x': 25, 'y': 55}], 'prize': {'x': 19756, 'y': 6071}}
# {'buttons': [{'id': 'A', 'x': 35, 'y': 59}, {'id': 'B', 'x': 44, 'y': 13}], 'prize': {'x': 13133, 'y': 17678}}
# {'buttons': [{'id': 'A', 'x': 50, 'y': 88}, {'id': 'B', 'x': 55, 'y': 11}], 'prize': {'x': 3750, 'y': 4884}}
# {'buttons': [{'id': 'A', 'x': 58, 'y': 11}, {'id': 'B', 'x': 28, 'y': 79}], 'prize': {'x': 17888, 'y': 10119}}
# {'buttons': [{'id': 'A', 'x': 42, 'y': 13}, {'id': 'B', 'x': 24, 'y': 72}], 'prize': {'x': 13454, 'y': 5951}}
# {'buttons': [{'id': 'A', 'x': 48, 'y': 86}, {'id': 'B', 'x': 95, 'y': 37}], 'prize': {'x': 8861, 'y': 6951}}
# {'buttons': [{'id': 'A', 'x': 23, 'y': 41}, {'id': 'B', 'x': 48, 'y': 19}], 'prize': {'x': 2536, 'y': 10671}}
# {'buttons': [{'id': 'A', 'x': 21, 'y': 90}, {'id': 'B', 'x': 69, 'y': 50}], 'prize': {'x': 7248, 'y': 7720}}
# {'buttons': [{'id': 'A', 'x': 72, 'y': 20}, {'id': 'B', 'x': 23, 'y': 44}], 'prize': {'x': 6016, 'y': 4680}}
# {'buttons': [{'id': 'A', 'x': 22, 'y': 74}, {'id': 'B', 'x': 97, 'y': 15}], 'prize': {'x': 4605, 'y': 4595}}
# {'buttons': [{'id': 'A', 'x': 65, 'y': 24}, {'id': 'B', 'x': 21, 'y': 67}], 'prize': {'x': 11600, 'y': 3087}}
# {'buttons': [{'id': 'A', 'x': 20, 'y': 43}, {'id': 'B', 'x': 63, 'y': 36}], 'prize': {'x': 9933, 'y': 3250}}
# {'buttons': [{'id': 'A', 'x': 20, 'y': 55}, {'id': 'B', 'x': 66, 'y': 18}], 'prize': {'x': 13846, 'y': 2553}}
# {'buttons': [{'id': 'A', 'x': 34, 'y': 13}, {'id': 'B', 'x': 12, 'y': 73}], 'prize': {'x': 3682, 'y': 7086}}
# {'buttons': [{'id': 'A', 'x': 60, 'y': 19}, {'id': 'B', 'x': 33, 'y': 69}], 'prize': {'x': 13223, 'y': 12155}}
# {'buttons': [{'id': 'A', 'x': 28, 'y': 42}, {'id': 'B', 'x': 37, 'y': 15}], 'prize': {'x': 3645, 'y': 15611}}
# {'buttons': [{'id': 'A', 'x': 12, 'y': 54}, {'id': 'B', 'x': 79, 'y': 30}], 'prize': {'x': 10411, 'y': 5000}}
# {'buttons': [{'id': 'A', 'x': 12, 'y': 74}, {'id': 'B', 'x': 94, 'y': 54}], 'prize': {'x': 1348, 'y': 6210}}
# {'buttons': [{'id': 'A', 'x': 91, 'y': 83}, {'id': 'B', 'x': 18, 'y': 71}], 'prize': {'x': 4155, 'y': 7283}}
# {'buttons': [{'id': 'A', 'x': 60, 'y': 22}, {'id': 'B', 'x': 16, 'y': 39}], 'prize': {'x': 4008, 'y': 8271}}
# {'buttons': [{'id': 'A', 'x': 66, 'y': 13}, {'id': 'B', 'x': 28, 'y': 73}], 'prize': {'x': 5356, 'y': 12695}}
# {'buttons': [{'id': 'A', 'x': 70, 'y': 52}, {'id': 'B', 'x': 23, 'y': 99}], 'prize': {'x': 4471, 'y': 5533}}
# {'buttons': [{'id': 'A', 'x': 43, 'y': 11}, {'id': 'B', 'x': 23, 'y': 80}], 'prize': {'x': 10179, 'y': 10780}}
# {'buttons': [{'id': 'A', 'x': 69, 'y': 23}, {'id': 'B', 'x': 19, 'y': 69}], 'prize': {'x': 9347, 'y': 1273}}
# {'buttons': [{'id': 'A', 'x': 59, 'y': 17}, {'id': 'B', 'x': 28, 'y': 77}], 'prize': {'x': 11805, 'y': 11525}}
# {'buttons': [{'id': 'A', 'x': 58, 'y': 22}, {'id': 'B', 'x': 19, 'y': 65}], 'prize': {'x': 16589, 'y': 19695}}
# {'buttons': [{'id': 'A', 'x': 19, 'y': 57}, {'id': 'B', 'x': 77, 'y': 37}], 'prize': {'x': 19364, 'y': 3220}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 49}, {'id': 'B', 'x': 76, 'y': 34}], 'prize': {'x': 6288, 'y': 4758}}
# {'buttons': [{'id': 'A', 'x': 69, 'y': 42}, {'id': 'B', 'x': 25, 'y': 47}], 'prize': {'x': 11514, 'y': 9841}}
# {'buttons': [{'id': 'A', 'x': 18, 'y': 43}, {'id': 'B', 'x': 45, 'y': 14}], 'prize': {'x': 17414, 'y': 11617}}
# {'buttons': [{'id': 'A', 'x': 31, 'y': 76}, {'id': 'B', 'x': 44, 'y': 12}], 'prize': {'x': 14828, 'y': 6268}}
# {'buttons': [{'id': 'A', 'x': 56, 'y': 20}, {'id': 'B', 'x': 30, 'y': 74}], 'prize': {'x': 11034, 'y': 2094}}
# {'buttons': [{'id': 'A', 'x': 43, 'y': 12}, {'id': 'B', 'x': 17, 'y': 57}], 'prize': {'x': 19364, 'y': 5468}}
# {'buttons': [{'id': 'A', 'x': 67, 'y': 59}, {'id': 'B', 'x': 19, 'y': 65}], 'prize': {'x': 7034, 'y': 9766}}
# {'buttons': [{'id': 'A', 'x': 29, 'y': 11}, {'id': 'B', 'x': 41, 'y': 69}], 'prize': {'x': 5890, 'y': 11210}}
# {'buttons': [{'id': 'A', 'x': 58, 'y': 11}, {'id': 'B', 'x': 33, 'y': 76}], 'prize': {'x': 10653, 'y': 16936}}
# {'buttons': [{'id': 'A', 'x': 32, 'y': 11}, {'id': 'B', 'x': 47, 'y': 60}], 'prize': {'x': 5639, 'y': 5139}}
# {'buttons': [{'id': 'A', 'x': 78, 'y': 36}, {'id': 'B', 'x': 20, 'y': 87}], 'prize': {'x': 1568, 'y': 1968}}
# {'buttons': [{'id': 'A', 'x': 45, 'y': 18}, {'id': 'B', 'x': 26, 'y': 58}], 'prize': {'x': 9398, 'y': 9230}}
# {'buttons': [{'id': 'A', 'x': 20, 'y': 47}, {'id': 'B', 'x': 69, 'y': 12}], 'prize': {'x': 4887, 'y': 2025}}
# {'buttons': [{'id': 'A', 'x': 79, 'y': 39}, {'id': 'B', 'x': 12, 'y': 35}], 'prize': {'x': 1947, 'y': 11830}}
# {'buttons': [{'id': 'A', 'x': 61, 'y': 23}, {'id': 'B', 'x': 31, 'y': 54}], 'prize': {'x': 3652, 'y': 3281}}
# {'buttons': [{'id': 'A', 'x': 14, 'y': 32}, {'id': 'B', 'x': 46, 'y': 31}], 'prize': {'x': 10154, 'y': 8327}}
# {'buttons': [{'id': 'A', 'x': 73, 'y': 81}, {'id': 'B', 'x': 89, 'y': 23}], 'prize': {'x': 11441, 'y': 5877}}
# {'buttons': [{'id': 'A', 'x': 54, 'y': 59}, {'id': 'B', 'x': 14, 'y': 94}], 'prize': {'x': 5582, 'y': 13497}}
# {'buttons': [{'id': 'A', 'x': 58, 'y': 69}, {'id': 'B', 'x': 13, 'y': 74}], 'prize': {'x': 6234, 'y': 11982}}
# {'buttons': [{'id': 'A', 'x': 22, 'y': 91}, {'id': 'B', 'x': 40, 'y': 35}], 'prize': {'x': 3284, 'y': 7322}}
# {'buttons': [{'id': 'A', 'x': 32, 'y': 50}, {'id': 'B', 'x': 42, 'y': 17}], 'prize': {'x': 6042, 'y': 3419}}
# {'buttons': [{'id': 'A', 'x': 87, 'y': 66}, {'id': 'B', 'x': 21, 'y': 85}], 'prize': {'x': 2691, 'y': 2594}}
# {'buttons': [{'id': 'A', 'x': 19, 'y': 42}, {'id': 'B', 'x': 45, 'y': 27}], 'prize': {'x': 5133, 'y': 2426}}
# {'buttons': [{'id': 'A', 'x': 53, 'y': 77}, {'id': 'B', 'x': 63, 'y': 25}], 'prize': {'x': 8172, 'y': 8280}}
# {'buttons': [{'id': 'A', 'x': 77, 'y': 50}, {'id': 'B', 'x': 12, 'y': 28}], 'prize': {'x': 8972, 'y': 15248}}
# {'buttons': [{'id': 'A', 'x': 79, 'y': 57}, {'id': 'B', 'x': 39, 'y': 93}], 'prize': {'x': 6206, 'y': 9018}}
# {'buttons': [{'id': 'A', 'x': 41, 'y': 27}, {'id': 'B', 'x': 15, 'y': 56}], 'prize': {'x': 1331, 'y': 1061}}
# {'buttons': [{'id': 'A', 'x': 65, 'y': 70}, {'id': 'B', 'x': 96, 'y': 17}], 'prize': {'x': 8090, 'y': 4825}}
# {'buttons': [{'id': 'A', 'x': 61, 'y': 19}, {'id': 'B', 'x': 23, 'y': 64}], 'prize': {'x': 8957, 'y': 12589}}
# {'buttons': [{'id': 'A', 'x': 22, 'y': 37}, {'id': 'B', 'x': 50, 'y': 18}], 'prize': {'x': 10098, 'y': 11920}}
# {'buttons': [{'id': 'A', 'x': 84, 'y': 63}, {'id': 'B', 'x': 24, 'y': 64}], 'prize': {'x': 3840, 'y': 6376}}
# {'buttons': [{'id': 'A', 'x': 14, 'y': 33}, {'id': 'B', 'x': 21, 'y': 12}], 'prize': {'x': 3441, 'y': 16127}}
# {'buttons': [{'id': 'A', 'x': 37, 'y': 83}, {'id': 'B', 'x': 42, 'y': 11}], 'prize': {'x': 13194, 'y': 3217}}
# {'buttons': [{'id': 'A', 'x': 32, 'y': 56}, {'id': 'B', 'x': 64, 'y': 14}], 'prize': {'x': 1280, 'y': 1162}}
# {'buttons': [{'id': 'A', 'x': 74, 'y': 17}, {'id': 'B', 'x': 48, 'y': 82}], 'prize': {'x': 3868, 'y': 2450}}
# {'buttons': [{'id': 'A', 'x': 42, 'y': 19}, {'id': 'B', 'x': 44, 'y': 63}], 'prize': {'x': 8028, 'y': 3786}}
# {'buttons': [{'id': 'A', 'x': 72, 'y': 61}, {'id': 'B', 'x': 15, 'y': 90}], 'prize': {'x': 5538, 'y': 9484}}
# {'buttons': [{'id': 'A', 'x': 89, 'y': 69}, {'id': 'B', 'x': 13, 'y': 53}], 'prize': {'x': 703, 'y': 1103}}
# {'buttons': [{'id': 'A', 'x': 80, 'y': 75}, {'id': 'B', 'x': 64, 'y': 13}], 'prize': {'x': 1680, 'y': 1105}}
# {'buttons': [{'id': 'A', 'x': 19, 'y': 42}, {'id': 'B', 'x': 60, 'y': 28}], 'prize': {'x': 15981, 'y': 17742}}
# {'buttons': [{'id': 'A', 'x': 40, 'y': 66}, {'id': 'B', 'x': 26, 'y': 13}], 'prize': {'x': 4274, 'y': 14791}}
# {'buttons': [{'id': 'A', 'x': 63, 'y': 14}, {'id': 'B', 'x': 35, 'y': 82}], 'prize': {'x': 2027, 'y': 2998}}
# {'buttons': [{'id': 'A', 'x': 22, 'y': 95}, {'id': 'B', 'x': 83, 'y': 52}], 'prize': {'x': 5319, 'y': 9180}}
# {'buttons': [{'id': 'A', 'x': 35, 'y': 67}, {'id': 'B', 'x': 82, 'y': 17}], 'prize': {'x': 7528, 'y': 3353}}
# {'buttons': [{'id': 'A', 'x': 49, 'y': 15}, {'id': 'B', 'x': 35, 'y': 62}], 'prize': {'x': 18295, 'y': 16461}}
# {'buttons': [{'id': 'A', 'x': 12, 'y': 47}, {'id': 'B', 'x': 49, 'y': 25}], 'prize': {'x': 6301, 'y': 1187}}
# {'buttons': [{'id': 'A', 'x': 99, 'y': 23}, {'id': 'B', 'x': 70, 'y': 70}], 'prize': {'x': 7729, 'y': 2333}}
# {'buttons': [{'id': 'A', 'x': 30, 'y': 12}, {'id': 'B', 'x': 32, 'y': 57}], 'prize': {'x': 18584, 'y': 236}}
# {'buttons': [{'id': 'A', 'x': 16, 'y': 77}, {'id': 'B', 'x': 54, 'y': 59}], 'prize': {'x': 3868, 'y': 5357}}
# {'buttons': [{'id': 'A', 'x': 61, 'y': 33}, {'id': 'B', 'x': 44, 'y': 89}], 'prize': {'x': 3297, 'y': 6217}}
# {'buttons': [{'id': 'A', 'x': 97, 'y': 20}, {'id': 'B', 'x': 99, 'y': 95}], 'prize': {'x': 11985, 'y': 4485}}
# {'buttons': [{'id': 'A', 'x': 58, 'y': 28}, {'id': 'B', 'x': 11, 'y': 30}], 'prize': {'x': 7771, 'y': 470}}
# {'buttons': [{'id': 'A', 'x': 40, 'y': 57}, {'id': 'B', 'x': 29, 'y': 13}], 'prize': {'x': 1079, 'y': 17843}}
# {'buttons': [{'id': 'A', 'x': 14, 'y': 55}, {'id': 'B', 'x': 96, 'y': 44}], 'prize': {'x': 7434, 'y': 5885}}
# {'buttons': [{'id': 'A', 'x': 29, 'y': 14}, {'id': 'B', 'x': 46, 'y': 68}], 'prize': {'x': 4400, 'y': 800}}
# {'buttons': [{'id': 'A', 'x': 46, 'y': 18}, {'id': 'B', 'x': 23, 'y': 61}], 'prize': {'x': 11278, 'y': 6842}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 72}, {'id': 'B', 'x': 73, 'y': 18}], 'prize': {'x': 7026, 'y': 2214}}
# {'buttons': [{'id': 'A', 'x': 24, 'y': 64}, {'id': 'B', 'x': 56, 'y': 36}], 'prize': {'x': 5992, 'y': 7932}}
# {'buttons': [{'id': 'A', 'x': 11, 'y': 27}, {'id': 'B', 'x': 31, 'y': 20}], 'prize': {'x': 13884, 'y': 7714}}
# {'buttons': [{'id': 'A', 'x': 28, 'y': 63}, {'id': 'B', 'x': 55, 'y': 21}], 'prize': {'x': 10058, 'y': 10973}}
# {'buttons': [{'id': 'A', 'x': 54, 'y': 31}, {'id': 'B', 'x': 12, 'y': 34}], 'prize': {'x': 16424, 'y': 12096}}
# {'buttons': [{'id': 'A', 'x': 17, 'y': 36}, {'id': 'B', 'x': 35, 'y': 19}], 'prize': {'x': 17833, 'y': 4568}}
# {'buttons': [{'id': 'A', 'x': 67, 'y': 11}, {'id': 'B', 'x': 12, 'y': 68}], 'prize': {'x': 454, 'y': 734}}
# {'buttons': [{'id': 'A', 'x': 95, 'y': 28}, {'id': 'B', 'x': 39, 'y': 80}], 'prize': {'x': 7467, 'y': 4804}}
# {'buttons': [{'id': 'A', 'x': 91, 'y': 11}, {'id': 'B', 'x': 44, 'y': 38}], 'prize': {'x': 7230, 'y': 972}}
# {'buttons': [{'id': 'A', 'x': 29, 'y': 15}, {'id': 'B', 'x': 44, 'y': 70}], 'prize': {'x': 15362, 'y': 770}}
# {'buttons': [{'id': 'A', 'x': 21, 'y': 82}, {'id': 'B', 'x': 96, 'y': 93}], 'prize': {'x': 2883, 'y': 4211}}
# {'buttons': [{'id': 'A', 'x': 24, 'y': 40}, {'id': 'B', 'x': 38, 'y': 13}], 'prize': {'x': 17268, 'y': 14074}}
# {'buttons': [{'id': 'A', 'x': 56, 'y': 14}, {'id': 'B', 'x': 27, 'y': 64}], 'prize': {'x': 10108, 'y': 12132}}
# {'buttons': [{'id': 'A', 'x': 72, 'y': 28}, {'id': 'B', 'x': 19, 'y': 49}], 'prize': {'x': 9350, 'y': 5422}}
# {'buttons': [{'id': 'A', 'x': 20, 'y': 63}, {'id': 'B', 'x': 68, 'y': 29}], 'prize': {'x': 14884, 'y': 3359}}
# {'buttons': [{'id': 'A', 'x': 76, 'y': 45}, {'id': 'B', 'x': 13, 'y': 34}], 'prize': {'x': 10079, 'y': 6852}}
# {'buttons': [{'id': 'A', 'x': 57, 'y': 25}, {'id': 'B', 'x': 22, 'y': 50}], 'prize': {'x': 5024, 'y': 9200}}
# {'buttons': [{'id': 'A', 'x': 51, 'y': 15}, {'id': 'B', 'x': 26, 'y': 49}], 'prize': {'x': 19153, 'y': 10212}}
# {'buttons': [{'id': 'A', 'x': 49, 'y': 13}, {'id': 'B', 'x': 17, 'y': 42}], 'prize': {'x': 14483, 'y': 10790}}
# {'buttons': [{'id': 'A', 'x': 70, 'y': 20}, {'id': 'B', 'x': 20, 'y': 68}], 'prize': {'x': 18570, 'y': 5644}}
# {'buttons': [{'id': 'A', 'x': 14, 'y': 22}, {'id': 'B', 'x': 40, 'y': 12}], 'prize': {'x': 16792, 'y': 13256}}
# {'buttons': [{'id': 'A', 'x': 33, 'y': 19}, {'id': 'B', 'x': 17, 'y': 36}], 'prize': {'x': 13698, 'y': 9914}}
# {'buttons': [{'id': 'A', 'x': 52, 'y': 20}, {'id': 'B', 'x': 39, 'y': 67}], 'prize': {'x': 1875, 'y': 16879}}
# {'buttons': [{'id': 'A', 'x': 46, 'y': 27}, {'id': 'B', 'x': 11, 'y': 32}], 'prize': {'x': 2330, 'y': 3360}}
# {'buttons': [{'id': 'A', 'x': 17, 'y': 55}, {'id': 'B', 'x': 78, 'y': 32}], 'prize': {'x': 8815, 'y': 5415}}
# {'buttons': [{'id': 'A', 'x': 29, 'y': 54}, {'id': 'B', 'x': 49, 'y': 28}], 'prize': {'x': 17077, 'y': 5982}}
# {'buttons': [{'id': 'A', 'x': 55, 'y': 24}, {'id': 'B', 'x': 26, 'y': 55}], 'prize': {'x': 5285, 'y': 2627}}
# {'buttons': [{'id': 'A', 'x': 26, 'y': 83}, {'id': 'B', 'x': 67, 'y': 14}], 'prize': {'x': 15367, 'y': 4847}}
# {'buttons': [{'id': 'A', 'x': 44, 'y': 11}, {'id': 'B', 'x': 29, 'y': 36}], 'prize': {'x': 4444, 'y': 2376}}
# {'buttons': [{'id': 'A', 'x': 21, 'y': 80}, {'id': 'B', 'x': 57, 'y': 47}], 'prize': {'x': 4218, 'y': 5860}}
# {'buttons': [{'id': 'A', 'x': 40, 'y': 33}, {'id': 'B', 'x': 20, 'y': 82}], 'prize': {'x': 3120, 'y': 4801}}
# {'buttons': [{'id': 'A', 'x': 63, 'y': 25}, {'id': 'B', 'x': 32, 'y': 71}], 'prize': {'x': 18027, 'y': 18881}}
# {'buttons': [{'id': 'A', 'x': 50, 'y': 24}, {'id': 'B', 'x': 34, 'y': 55}], 'prize': {'x': 15958, 'y': 5573}}
# {'buttons': [{'id': 'A', 'x': 44, 'y': 15}, {'id': 'B', 'x': 42, 'y': 75}], 'prize': {'x': 4594, 'y': 8075}}
# {'buttons': [{'id': 'A', 'x': 79, 'y': 14}, {'id': 'B', 'x': 14, 'y': 66}], 'prize': {'x': 15594, 'y': 18740}}
# {'buttons': [{'id': 'A', 'x': 43, 'y': 22}, {'id': 'B', 'x': 25, 'y': 61}], 'prize': {'x': 2431, 'y': 14665}}
# {'buttons': [{'id': 'A', 'x': 34, 'y': 15}, {'id': 'B', 'x': 55, 'y': 80}], 'prize': {'x': 5061, 'y': 19525}}
# {'buttons': [{'id': 'A', 'x': 62, 'y': 26}, {'id': 'B', 'x': 17, 'y': 64}], 'prize': {'x': 9784, 'y': 1512}}
# {'buttons': [{'id': 'A', 'x': 83, 'y': 70}, {'id': 'B', 'x': 90, 'y': 14}], 'prize': {'x': 4430, 'y': 1260}}
# {'buttons': [{'id': 'A', 'x': 16, 'y': 56}, {'id': 'B', 'x': 98, 'y': 89}], 'prize': {'x': 5182, 'y': 8231}}
# {'buttons': [{'id': 'A', 'x': 82, 'y': 22}, {'id': 'B', 'x': 14, 'y': 69}], 'prize': {'x': 1948, 'y': 6833}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 85}, {'id': 'B', 'x': 70, 'y': 49}], 'prize': {'x': 6114, 'y': 10959}}
# {'buttons': [{'id': 'A', 'x': 44, 'y': 18}, {'id': 'B', 'x': 28, 'y': 47}], 'prize': {'x': 2212, 'y': 3103}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 69}, {'id': 'B', 'x': 56, 'y': 17}], 'prize': {'x': 6392, 'y': 19322}}
# {'buttons': [{'id': 'A', 'x': 48, 'y': 22}, {'id': 'B', 'x': 45, 'y': 74}], 'prize': {'x': 6398, 'y': 3396}}
# {'buttons': [{'id': 'A', 'x': 26, 'y': 51}, {'id': 'B', 'x': 54, 'y': 24}], 'prize': {'x': 19354, 'y': 4439}}
# {'buttons': [{'id': 'A', 'x': 75, 'y': 58}, {'id': 'B', 'x': 23, 'y': 89}], 'prize': {'x': 4823, 'y': 9142}}
# {'buttons': [{'id': 'A', 'x': 96, 'y': 99}, {'id': 'B', 'x': 91, 'y': 11}], 'prize': {'x': 6900, 'y': 2145}}
# {'buttons': [{'id': 'A', 'x': 21, 'y': 33}, {'id': 'B', 'x': 90, 'y': 46}], 'prize': {'x': 6507, 'y': 5263}}
# {'buttons': [{'id': 'A', 'x': 14, 'y': 56}, {'id': 'B', 'x': 58, 'y': 19}], 'prize': {'x': 2042, 'y': 7430}}
# {'buttons': [{'id': 'A', 'x': 21, 'y': 68}, {'id': 'B', 'x': 58, 'y': 14}], 'prize': {'x': 16150, 'y': 6700}}
# {'buttons': [{'id': 'A', 'x': 17, 'y': 25}, {'id': 'B', 'x': 42, 'y': 20}], 'prize': {'x': 1407, 'y': 1025}}
# {'buttons': [{'id': 'A', 'x': 54, 'y': 12}, {'id': 'B', 'x': 16, 'y': 33}], 'prize': {'x': 11024, 'y': 5417}}
# {'buttons': [{'id': 'A', 'x': 40, 'y': 18}, {'id': 'B', 'x': 11, 'y': 53}], 'prize': {'x': 11988, 'y': 208}}
# {'buttons': [{'id': 'A', 'x': 69, 'y': 13}, {'id': 'B', 'x': 23, 'y': 66}], 'prize': {'x': 3412, 'y': 11169}}
# {'buttons': [{'id': 'A', 'x': 16, 'y': 29}, {'id': 'B', 'x': 58, 'y': 25}], 'prize': {'x': 6044, 'y': 1039}}
# {'buttons': [{'id': 'A', 'x': 15, 'y': 58}, {'id': 'B', 'x': 48, 'y': 15}], 'prize': {'x': 13937, 'y': 8507}}
# {'buttons': [{'id': 'A', 'x': 22, 'y': 43}, {'id': 'B', 'x': 80, 'y': 45}], 'prize': {'x': 7612, 'y': 5078}}
# {'buttons': [{'id': 'A', 'x': 12, 'y': 48}, {'id': 'B', 'x': 51, 'y': 13}], 'prize': {'x': 6077, 'y': 10599}}
# {'buttons': [{'id': 'A', 'x': 44, 'y': 80}, {'id': 'B', 'x': 46, 'y': 12}], 'prize': {'x': 8964, 'y': 8672}}
# {'buttons': [{'id': 'A', 'x': 76, 'y': 17}, {'id': 'B', 'x': 13, 'y': 74}], 'prize': {'x': 11822, 'y': 12878}}
# {'buttons': [{'id': 'A', 'x': 98, 'y': 24}, {'id': 'B', 'x': 47, 'y': 57}], 'prize': {'x': 6211, 'y': 4023}}
# {'buttons': [{'id': 'A', 'x': 15, 'y': 67}, {'id': 'B', 'x': 21, 'y': 17}], 'prize': {'x': 531, 'y': 759}}
# {'buttons': [{'id': 'A', 'x': 60, 'y': 88}, {'id': 'B', 'x': 88, 'y': 24}], 'prize': {'x': 4384, 'y': 5064}}
# {'buttons': [{'id': 'A', 'x': 15, 'y': 64}, {'id': 'B', 'x': 79, 'y': 17}], 'prize': {'x': 1302, 'y': 434}}
# {'buttons': [{'id': 'A', 'x': 11, 'y': 35}, {'id': 'B', 'x': 72, 'y': 24}], 'prize': {'x': 10642, 'y': 9538}}
# {'buttons': [{'id': 'A', 'x': 14, 'y': 27}, {'id': 'B', 'x': 92, 'y': 21}], 'prize': {'x': 1256, 'y': 1953}}
# {'buttons': [{'id': 'A', 'x': 49, 'y': 16}, {'id': 'B', 'x': 31, 'y': 69}], 'prize': {'x': 12481, 'y': 7539}}
# {'buttons': [{'id': 'A', 'x': 33, 'y': 61}, {'id': 'B', 'x': 55, 'y': 19}], 'prize': {'x': 8405, 'y': 10385}}
# {'buttons': [{'id': 'A', 'x': 40, 'y': 94}, {'id': 'B', 'x': 77, 'y': 28}], 'prize': {'x': 6615, 'y': 4074}}
# {'buttons': [{'id': 'A', 'x': 90, 'y': 56}, {'id': 'B', 'x': 31, 'y': 76}], 'prize': {'x': 7890, 'y': 8312}}
# {'buttons': [{'id': 'A', 'x': 42, 'y': 99}, {'id': 'B', 'x': 75, 'y': 38}], 'prize': {'x': 9639, 'y': 10091}}
# {'buttons': [{'id': 'A', 'x': 15, 'y': 93}, {'id': 'B', 'x': 62, 'y': 40}], 'prize': {'x': 6871, 'y': 8849}}
# {'buttons': [{'id': 'A', 'x': 15, 'y': 46}, {'id': 'B', 'x': 32, 'y': 18}], 'prize': {'x': 3296, 'y': 18792}}
# {'buttons': [{'id': 'A', 'x': 64, 'y': 83}, {'id': 'B', 'x': 83, 'y': 21}], 'prize': {'x': 6251, 'y': 7327}}
# {'buttons': [{'id': 'A', 'x': 12, 'y': 46}, {'id': 'B', 'x': 32, 'y': 17}], 'prize': {'x': 18328, 'y': 2824}}
# {'buttons': [{'id': 'A', 'x': 33, 'y': 61}, {'id': 'B', 'x': 50, 'y': 26}], 'prize': {'x': 1929, 'y': 1573}}
# {'buttons': [{'id': 'A', 'x': 19, 'y': 51}, {'id': 'B', 'x': 61, 'y': 36}], 'prize': {'x': 12007, 'y': 1517}}
# {'buttons': [{'id': 'A', 'x': 33, 'y': 82}, {'id': 'B', 'x': 86, 'y': 67}], 'prize': {'x': 11080, 'y': 14036}}
# {'buttons': [{'id': 'A', 'x': 11, 'y': 29}, {'id': 'B', 'x': 70, 'y': 31}], 'prize': {'x': 662, 'y': 10319}}
# {'buttons': [{'id': 'A', 'x': 35, 'y': 82}, {'id': 'B', 'x': 95, 'y': 50}], 'prize': {'x': 1560, 'y': 2792}}
# {'buttons': [{'id': 'A', 'x': 21, 'y': 43}, {'id': 'B', 'x': 42, 'y': 27}], 'prize': {'x': 18239, 'y': 15806}}
# {'buttons': [{'id': 'A', 'x': 46, 'y': 23}, {'id': 'B', 'x': 21, 'y': 37}], 'prize': {'x': 19135, 'y': 12376}}
# {'buttons': [{'id': 'A', 'x': 97, 'y': 17}, {'id': 'B', 'x': 36, 'y': 78}], 'prize': {'x': 4100, 'y': 5020}}
# {'buttons': [{'id': 'A', 'x': 28, 'y': 59}, {'id': 'B', 'x': 85, 'y': 12}], 'prize': {'x': 5343, 'y': 2736}}
# {'buttons': [{'id': 'A', 'x': 12, 'y': 61}, {'id': 'B', 'x': 82, 'y': 28}], 'prize': {'x': 13438, 'y': 17825}}
# {'buttons': [{'id': 'A', 'x': 41, 'y': 71}, {'id': 'B', 'x': 47, 'y': 15}], 'prize': {'x': 15081, 'y': 7637}}
# {'buttons': [{'id': 'A', 'x': 90, 'y': 61}, {'id': 'B', 'x': 16, 'y': 85}], 'prize': {'x': 5320, 'y': 9909}}
# {'buttons': [{'id': 'A', 'x': 80, 'y': 42}, {'id': 'B', 'x': 15, 'y': 53}], 'prize': {'x': 4955, 'y': 2827}}
# {'buttons': [{'id': 'A', 'x': 14, 'y': 33}, {'id': 'B', 'x': 60, 'y': 37}], 'prize': {'x': 19110, 'y': 8006}}
# {'buttons': [{'id': 'A', 'x': 63, 'y': 29}, {'id': 'B', 'x': 12, 'y': 27}], 'prize': {'x': 7448, 'y': 10341}}
# {'buttons': [{'id': 'A', 'x': 68, 'y': 22}, {'id': 'B', 'x': 13, 'y': 33}], 'prize': {'x': 5537, 'y': 11837}}
# {'buttons': [{'id': 'A', 'x': 54, 'y': 24}, {'id': 'B', 'x': 28, 'y': 54}], 'prize': {'x': 13884, 'y': 428}}
# {'buttons': [{'id': 'A', 'x': 62, 'y': 27}, {'id': 'B', 'x': 21, 'y': 62}], 'prize': {'x': 18196, 'y': 11975}}
# {'buttons': [{'id': 'A', 'x': 53, 'y': 78}, {'id': 'B', 'x': 33, 'y': 14}], 'prize': {'x': 12540, 'y': 13480}}
# {'buttons': [{'id': 'A', 'x': 26, 'y': 32}, {'id': 'B', 'x': 15, 'y': 98}], 'prize': {'x': 3291, 'y': 10334}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 47}, {'id': 'B', 'x': 29, 'y': 11}], 'prize': {'x': 10839, 'y': 18181}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 99}, {'id': 'B', 'x': 54, 'y': 26}], 'prize': {'x': 4851, 'y': 6509}}
# {'buttons': [{'id': 'A', 'x': 63, 'y': 12}, {'id': 'B', 'x': 23, 'y': 90}], 'prize': {'x': 3708, 'y': 3018}}
# {'buttons': [{'id': 'A', 'x': 13, 'y': 51}, {'id': 'B', 'x': 65, 'y': 60}], 'prize': {'x': 5330, 'y': 5700}}
# {'buttons': [{'id': 'A', 'x': 57, 'y': 37}, {'id': 'B', 'x': 27, 'y': 89}], 'prize': {'x': 2391, 'y': 3053}}
# {'buttons': [{'id': 'A', 'x': 14, 'y': 32}, {'id': 'B', 'x': 27, 'y': 19}], 'prize': {'x': 15478, 'y': 6572}}
# {'buttons': [{'id': 'A', 'x': 79, 'y': 15}, {'id': 'B', 'x': 46, 'y': 49}], 'prize': {'x': 5806, 'y': 1344}}
# {'buttons': [{'id': 'A', 'x': 33, 'y': 38}, {'id': 'B', 'x': 13, 'y': 72}], 'prize': {'x': 1700, 'y': 6520}}
# {'buttons': [{'id': 'A', 'x': 11, 'y': 43}, {'id': 'B', 'x': 74, 'y': 42}], 'prize': {'x': 6025, 'y': 16265}}
# 26599
